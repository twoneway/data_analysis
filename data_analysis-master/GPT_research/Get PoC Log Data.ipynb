# %%
# !pip install mysql-connector-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-8.0.32-cp39-cp39-manylinux1_x86_64.whl (23.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 19.2 MB/s eta 0:00:00
# Requirement already satisfied: protobuf<=3.20.3,>=3.11.0 in /usr/local/lib/python3.9/dist-packages (from mysql-connector-python) (3.20.3)
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-8.0.32

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="server.hyungyu.com",
  user="admin",
  password="sktmekr88!",
  database="responseDB"
)

userCode = "Dpfc8Muo" # PoC Framing 주소 내 userID 가져오기

mycursor = mydb.cursor()

mycursor.execute("SELECT user_id from userCodeTable where code='" + userCode + "'")

myresult = mycursor.fetchall()

userID = myresult[0][0]

mycursor.execute("SELECT user_id, question_id, response FROM responseTable where user_id='" + str(userID) + "'")

myresult = mycursor.fetchall()

userResponse = {}

for x in myresult:
    userResponse[x[1]] = x[2]
    
userResponse
# Out:
# {0: 'y.comte',
#  1: '양혜성',
#  2: '3D데데이터',
#  3: '- 승/상용 디지털차량 제작 및 운영\n- 디지털차량 제작 및 조회를 위한 시스템 개발\n- 디지털 검증 결과 운영 시스템 개발',
#  4: ' 차량개발 중 디지털검증(DPA)이 수행되는 단계마다 디지털차량을 제작하고 있습니다. 제작 시 검증의 편의성을 위해 디지털부품간의 간섭/간극을 자동으로 체크하여 그 결과를 평가부서에 공유하고 있습니다. 평가부서는 공유된 내용을 바탕으로 실제 문제가 될지 안될지를 3D모델과 간섭/간극 수치를 기반으로 판단하여 시스템에 그 결과를 업로드하고, 설계담당자는 해당 검증결과에 대한 회신을 주고 있습니다.\n\n 매번 차량개발단계에 자동으로 생성되는 간섭/간극 갯수는 약 10000~100000만개 정도이고, 이 중 실제로 차량제작에 문제가 되는 것은 많아야 수백개 정도입니다. 이 데이터에 대해 10명 내외의 담당자가 개인의 노하우를 통해 문제여부를 판단하고 있으며, 선별에 상당히 오랜 시간이 소요 됩니다.\n 수년간 사람이 판단하는 방법으로 진행해왔기 때문에 현재 업무상 문제는 없지만, 인공지능을 통해 업무프로세스가 개선된다면 인적 리소스를 확보 할 수 있을 것이라 생각됩니다. 나아가 인공지능에 대한 신뢰도가 매우 높다면, 단순 간섭/간극을 검증하는것은 인공지능에게 전적으로 맡기고, 평가부서는 좀 더 높은 수준의 디지털검증을 수행하는데 시간을 쓸 수 있을 것으로 생각됩니다.\n\n이러한 인공지능의 신뢰도가 높다면 단순히 문제점을 선별해주는 것이 아닌, 100% 문제가 아니라고 판단하는 경우 간섭/간극을 계산하는 서버에서 계산을 하지 않게 하여 서버에 대한 리소스를 감소시키는 등 연계된 다른 부분들까지도 영향이 미칠 수 있다고 생각됩니다.\n ',
#  5: ' 현재까지 진행했던 차종/단계의 간섭/간극 데이터와 평가부서에서 업로드한 평가결과값, 설계담당자의 회신값을 통해 학습이 가능할 것 같으며, 이를 통해 평가부서에서 10000~100000개의 데이터 중 실제 문제가 발생할 것 같은 데이터만을 선별하여 우선적으로 검토하게 되면 검증에 소요되는 시간이 줄어들 것으로 판단 됩니다.\n 인공지능을 활용하기 위해 현재까지 검증부서에서 제기한 문제점 데이터에 대해 학습하여 패턴을 찾아낼 수 있을 것 같습니다.\n 여기에 앞으로 수행하는 프로젝트에 대해서 충분히 테스트하고 재학습 할 수 있는 데이터들이 꾸준히 쌓일 것으로 보입니다.\n\n',
#  6: 'AI DMU\n(https://www.invenio.net/en/virtual-technologies/vt-dmu-modules/)',
#  7: '계산된 10000~100000건의 간섭/간극 데이터 중에서 평가 담당자가 실제로 차량개발에 문제라고 판단하는 문제점에 대해 먼저 분류하여 제공함\n\n문제가 되는 데이터와 문제가 되지 않는 데이터에 대한 설명(각 사유에 대한 분류)도 해주면 좋을 듯',
#  8: '디지털검증 매 단계 시 간섭/간극 문제 판단 소요 시간 최소화 (10명 내외 5일 --> 10명 내외 1일)\n\n최종적으로는 단순 간섭/간극 문제 100% 인공지능 활용 (평가부서 M/H 제로화)\n\n실차 제작 시 간섭/간극 문제 제로화',
#  9: ' - 실제 평가 담당자가 제기한 문제점과의 비교 평가 (AUC, Precision, Recall)\n - 실제 문제인 것을 문제라고 하지 않는 경우가 크리티컬함 (Recall 0.85 이상)\n - 모델이 문제라고 하나 실제 문제가 아닌 경우는 크리티컬 하지 않음 (Precision 0.6 이상)\n',
#  10: ' - 데이터에 대한 문제여부 (0, 1)\n\n\n (발전된 형태가 된다면)\n - 문제 데이터의 문제분류 (간섭, 간극, 도면오류 등)\n - 문제되지 않은 데이터의 분류 (눌림을 반영한 설계, PAD/Sealer류, 용접정보 등)',
#  11: ' - 데이터에 대한 문제여부 (0, 1)\n\n\n (발전된 형태가 된다면)\n - 문제 데이터의 문제분류 (간섭, 간극, 도면오류 등)\n - 문제되지 않은 데이터의 문제가 아닌 분류 (눌림을 반영한 설계, PAD/Sealer류, 용접정보 등)',
#  12: '이전 단계에서 제기되었던 문제점들에 대한 정보를 이번 단계에서 활용\n과거 유사 차종에서 제기된 문제점들에 대한 데이터를 활용',
#  13: '현재의 평가부서 M/H를 지속 투입\n실차 위주의 평가 진행 지속 (디지털 차량개발로의 전환 불',
#  14: '1',
#  15: ' - 계산된 2개의 파트에 대한 간섭/간극 값에 대해 문제인지 아닌지 (Yes/No)\n - Yes/No에 대한 각각의 분류',
#  16: '0',
#  17: '3D데이터솔루션팀',
#  18: '본인이 해당 시스템 담당자로 권한부여/데이터 확보 가능\n다량의 데이터를 확보하기 위한 오토에버 운영 담당자의 협조 필요\n',
#  19: '부품정보, 차량 이미지 등이 포함되어 있을 수 있기 때문에 별도의 보안 절차가 필요할 것으로 보입니다.',
#  20: '레이블이 직접적으로 존재하진 않지만, 해당 문제가 관리페이지에 올라와 있음을 통해 Yes로 판단하여 쉽게 레이블을 생성할 수 있을 것으로',
#  21: '차종\n차급\n개발단계\n파트1의 UPG넘버\n파트1의 파트넘버\n파트1의 파트네임\n파트1의 재질\n파트1의 설계담당부서\n파트2의 UPG넘버\n파트2의 파트넘버\n파트2의 파트네임\n파트2의 재질\n파트1의 설계담당부서\n파트간거리 (+는 간극, -는 간섭, -999~+50 까지만 측정)\n파트간거리 계산 시 소요시간\n...\nLabel : 웹페이지 상 문제점 등록 여부\n(추후 발전이 가능하다면, 웹페이지에 등록된 정보 - 문제점이미지/평가담당자의 문제분류값/설계담당자의 회신값 등을 Label에 추가하여 멀티클래스 분류 진행)',
#  22: '현재 디지털차량 제작 시 활용하는 서버 Application 내 데이터\n관리하는 웹페이지 내 파트정보 등',
#  23: '차종\n차급\n개발단계\n파트1의 UPG넘버\n파트1의 파트넘버\n파트1의 파트네임\n파트1의 재질\n파트1의 설계담당부서\n파트2의 UPG넘버\n파트2의 파트넘버\n파트2의 파트네임\n파트2의 재질\n파트1의 설계담당부서\n파트간거리 (+는 간극, -는 간섭, -999~+50 까지만 측정)\nLabel : 웹페이지 상 문제점 등록 여부',
#  24: ''}
